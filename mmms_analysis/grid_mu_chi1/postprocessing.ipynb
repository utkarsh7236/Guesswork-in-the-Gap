# %%
import sys
import numpy
import matplotlib.pyplot as plt, pandas as pd, matplotlib as mpl, random
from scipy.ndimage import label


def utkarshGrid(): plt.minorticks_on() ; plt.grid(color='grey',which='minor',linestyle=":",linewidth='0.1',) ; plt.grid(color='black',which='major',linestyle=":",linewidth='0.1',); return None
def utkarshGridAX(ax): ax.minorticks_on() ; ax.grid(color='grey',which='minor',linestyle=":",linewidth='0.1',) ; ax.grid(color='black',which='major',linestyle=":",linewidth='0.1',); return None
mpl.rcParams['legend.frameon'], mpl.rcParams['figure.autolayout'] = False, True,
colour = ["dodgerblue", "goldenrod", "crimson", "teal", "yellowgreen", "grey"]
plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Palatino"],})
def utkarshWrapper(): plt.legend();plt.utkarshGrid() ;plt.gca().tick_params(direction='in', which='both', right=True, top=True); plt.tight_layout(); return None
def utkarshWrapperAX(ax): utkarshGridAX(ax); ax.tick_params(direction='in', which='both', right=True, top=True); return None;
plt.utkarshGrid = utkarshGrid; plt.utkarshWrapper = utkarshWrapper
def colour_sample(n = 2, col = colour, seed = 7236): random.seed(seed) ; return random.sample(colour, n)
plt.rcParams["image.cmap"] = "Set2" # I recommend, Set2, Dark2
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=colour) # Use your own OR plt.cm.Set2.colors

# %%
import os
import glob
import re
import pandas as pd

# Define pattern to match values from lines
prob_pattern = r"Probability: P\(mass <= max_mass\(spin, eos\)\) = ([\d\.eE+-]+) \+/- ([\d\.eE+-]+)"
odds_pattern = r"Odds Ratio\s*:.*= ([\d\.eE+-]+) \+/- ([\d\.eE+-]+)"

# Create list to hold parsed data
data = []

# Loop through all .out files
for filepath in glob.glob("*.out"):
    with open(filepath, "r") as f:
        content = f.read()

        prob_match = re.search(prob_pattern, content)
        odds_match = re.search(odds_pattern, content)

        if prob_match and odds_match:
            prob, prob_err = map(float, prob_match.groups())
            odds, odds_err = map(float, odds_match.groups())
            data.append({
                "filename": filepath,
                "probability": prob,
                "prob_error": prob_err,
                "odds_ratio": odds,
                "odds_error": odds_err
            })
        else:
            print(f"Warning: Could not parse values from {filepath}")

# Convert to pandas DataFrame
df = pd.DataFrame(data)
# Out:
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.08+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.4+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.4+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.32+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.18+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.04+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.24+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.36+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.16+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.06+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.38+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.0+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.16+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.18+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.3+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.32+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.22+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.2+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.08+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.12+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.0+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.26+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.3+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.1+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.14+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.28+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.38+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.22+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.26+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.06+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.02+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.12+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.2+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.04+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.24+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.34+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.1+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.34+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.02+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.28+component2.out
# Warning: Could not parse values from GW200115_C01:IMRPhenomNSBH:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.36+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+multiPDB_betaSplit_brokenG+mu_chi1+0.14+component2.out

# %%
df["mu_chi1"] = df["filename"].str.extract(r"mu_chi1\+([\d.]+)").astype(float)
df["event"] = df["filename"].str.extract(r"^(GW\d+)")
df["component"] = df["filename"].str.extract(r"component(\d+)").astype(int)

# %%
GW190917_m1 = df[(df['event'] == "GW190917") & (df['component'] == 1)].sort_values(by="mu_chi1").reset_index(drop=True)
GW190917_m2 = df[(df['event'] == "GW190917") & (df['component'] == 2)].sort_values(by="mu_chi1").reset_index(drop=True)
GW230529_m1 = df[(df['event'] == "GW230529") & (df['component'] == 1)].sort_values(by="mu_chi1").reset_index(drop=True)
GW190814_m2 = df[(df['event'] == "GW190814") & (df['component'] == 2)].sort_values(by="mu_chi1").reset_index(drop=True)
GW190425_m1 = df[(df['event'] == "GW190425") & (df['component'] == 1)].sort_values(by="mu_chi1").reset_index(drop=True)
GW190425_m2 = df[(df['event'] == "GW190425") & (df['component'] == 2)].sort_values(by="mu_chi1").reset_index(drop=True)
GW200105_m1 = df[(df['event'] == "GW200105") & (df['component'] == 1)].sort_values(by="mu_chi1").reset_index(drop=True)
GW200105_m2 = df[(df['event'] == "GW200105") & (df['component'] == 2)].sort_values(by="mu_chi1").reset_index(drop=True)
GW200115_m2 = df[(df['event'] == "GW200115") & (df['component'] == 2)].sort_values(by="mu_chi1").reset_index(drop=True)

# %%
plt.figure()
plt.plot(GW230529_m1["mu_chi1"], GW230529_m1["probability"], label="GW230529 primary")
plt.plot(GW190814_m2["mu_chi1"], GW190814_m2["probability"], label="GW190814 secondary")
plt.plot(GW190917_m2["mu_chi1"], GW190917_m2["probability"], label="GW190917 secondary")
plt.plot(GW190917_m1["mu_chi1"], GW190917_m1["probability"], label="GW190917 primary")
plt.plot(GW190425_m2["mu_chi1"], GW190425_m2["probability"], label="GW190425 secondary")
plt.plot(GW190425_m1["mu_chi1"], GW190425_m1["probability"], label="GW190425 primary")
plt.plot(GW200105_m2["mu_chi1"], GW200105_m2["probability"], label="GW200105 secondary")
plt.plot(GW200105_m1["mu_chi1"], GW200105_m1["probability"], label="GW200105 primary")
plt.plot(GW200115_m2["mu_chi1"], GW200115_m2["probability"], label="GW200115 secondary")
plt.ylabel("P(NS)")
plt.xlabel("mu_chi1")
plt.utkarshWrapper()
plt.show()
