# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
EOS_NAME="LEC-2020"
EOS_SAMPLES=f"../samples/{EOS_NAME}.csv.gz"

# %%
# !ls -lh $EOS_SAMPLES
# Out:
# -rw-r--r-- 1 mali cita 10M Jul 15 12:20 ../samples/LEC-2020.csv.gz

# %%
# Read EOS samples with pandas
eos_samples = pd.read_csv(EOS_SAMPLES)
# Display the first few rows of the EOS samples
eos_samples.head()
# Out:
#          EoS      Mmax  logweight_j1614  logweight_j0348  logweight_j0740  \
# 0  2020027.0  2.048305         3.244863         3.063584         1.510664
# 1   459969.0  2.244652         3.148846         3.148846         2.995982
# 2  1971432.0  2.033899         3.252285         2.937479         1.292724
# 3   462895.0  2.368022         3.092915         3.092915         3.082796
# 4  1324217.0  2.103741         3.216807         3.207405         2.191491
#
#    logweight_gw170817  logweight_gw190425  logweight_j0030  logweight_PSR  \
# 0           -1.171212            2.594206         0.869612       7.819112
# 1           -7.674211            2.060638         0.555482       9.293674
# 2            0.140612            2.535236         0.812203       7.482488
# 3            2.120821            2.859973        -5.649178       9.268625
# 4           -0.428794            2.655837         1.078767       8.615703
#
#    logweight_GW  logweight_Xray  logweight_PSR_GW  logweight_PSR_Xray  \
# ...

# %%
plt.hist(10**eos_samples["logweight_PSR_GW"])
plt.xscale("log")
