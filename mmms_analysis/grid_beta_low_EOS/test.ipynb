# %%
import pandas as pd

# Hardcoded file path
filename = "population3.5.csv.gz"

# Read and print the table
df = pd.read_csv(filename, compression='gzip')
df["notch_lowmass_exponent"]
# Out:
# 0       50.0
# 1       50.0
# 2       50.0
# 3       50.0
# 4       50.0
#         ...
# 4995    50.0
# 4996    50.0
# 4997    50.0
# 4998    50.0
# 4999    50.0
# Name: notch_lowmass_exponent, Length: 5000, dtype: float64
