# %%
import pandas as pd
import numpy as np
import gzip
from tqdm import tqdm

def read_csv_gz(file_path):
    with gzip.open(file_path, 'rt') as f:
        data = np.genfromtxt(f, delimiter=',', names=True, dtype=None, encoding='utf-8')
    return data


def save_csv_gz(data, file_path):
    # Get column names
    header = ','.join(data.dtype.names)

    # Save to compressed CSV
    with gzip.open(file_path, 'wt', encoding='utf-8') as f:
        np.savetxt(f, data, delimiter=',', header=header, comments='', fmt='%s')

# %%
df = read_csv_gz("Farah2022-i-PDB.csv.gz")
list(df.dtype.names)
# Out:
# ['Ho',
#  'Ncomp',
#  'OmegaLambda',
#  'OmegaMatter',
#  'OmegaRadiation',
#  'alpha0',
#  'alpha1',
#  'alpha_spin1_magnitude',
#  'alpha_spin2_magnitude',
#  'beta_spin1_magnitude',
#  'beta_spin2_magnitude',
#  'break1_mass1_source',
#  'highpass_exponent',
#  'highpass_mass_scale',
#  'lowpass_exponent',
#  'lowpass_mass_scale',
#  'max_mass1_source',
#  'max_redshift',
#  'max_spin1_magnitude',
#  'max_spin2_magnitude',
#  'min_mass1_source',
#  'min_redshift',
#  'min_spin1_magnitude',
#  'min_spin2_magnitude',
#  'notch_amplitude',
#  'notch_highmass_exponent',
#  'notch_highmass_scale',
#  'notch_lowmass_exponent',
#  'notch_lowmass_scale',
#  'pairing_mbreak',
#  'pairing_pow_q_high',
#  'pairing_pow_q_low',
#  'pow_redshift']

# %%
import time 

POP_VALUES = [2.2, 2.25, 2.3, 2.35, 2.4, 2.45, 2.5, 2.55, 2.6, 2.65, 2.7, 2.75, 2.8, 2.85, 2.9, 2.95, 3.0, 3.05, 3.1, 3.15, 3.2, 3.25, 3.3, 3.35, 3.4, 3.5, 3.5, 3.55, 3.6, 3.65, 3.7, 3.75, 3.8, 3.85, 3.9, 3.95, 4.0]

# df["notch_lowmass_exponent"] = np.ones(len(df), dtype=np.float32) * 0.001
# df["notch_amplitude"] = np.ones(len(df), dtype=np.float32) * 0

# for name in df.dtype.names:
#     if name in ['Ho', 'Ncomp','OmegaLambda','OmegaMatter','OmegaRadiation', 'min_redshift', 'max_redshift', "alpha0", "alpha1", "pairing_pow_q_high", "pairing_pow_q_low", "break1_mass1_source"]:
#         continue
#     df[name] = np.ones(len(df), dtype=np.float32) 


for pop in POP_VALUES:
    df["notch_lowmass_scale"] = np.ones(len(df), dtype=np.float32) * pop
    save_txt = f"PDBpopulation{float(pop)}.csv.gz"
    print(save_txt)
    save_csv_gz(df, save_txt)
# Out:
# PDBpopulation2.2.csv.gz
# PDBpopulation2.25.csv.gz
# PDBpopulation2.3.csv.gz
# PDBpopulation2.35.csv.gz
# PDBpopulation2.4.csv.gz
# PDBpopulation2.45.csv.gz
# PDBpopulation2.5.csv.gz
# PDBpopulation2.55.csv.gz
# PDBpopulation2.6.csv.gz
# PDBpopulation2.65.csv.gz
# PDBpopulation2.7.csv.gz
# PDBpopulation2.75.csv.gz
# PDBpopulation2.8.csv.gz
# PDBpopulation2.85.csv.gz
# PDBpopulation2.9.csv.gz
# PDBpopulation2.95.csv.gz
# PDBpopulation3.0.csv.gz
# PDBpopulation3.05.csv.gz
# PDBpopulation3.1.csv.gz
# PDBpopulation3.15.csv.gz
# PDBpopulation3.2.csv.gz
# PDBpopulation3.25.csv.gz
# PDBpopulation3.3.csv.gz
# PDBpopulation3.35.csv.gz
# PDBpopulation3.4.csv.gz
# PDBpopulation3.5.csv.gz
# PDBpopulation3.5.csv.gz
# PDBpopulation3.55.csv.gz
# PDBpopulation3.6.csv.gz
# PDBpopulation3.65.csv.gz
# PDBpopulation3.7.csv.gz
# PDBpopulation3.75.csv.gz
# PDBpopulation3.8.csv.gz
# PDBpopulation3.85.csv.gz
# PDBpopulation3.9.csv.gz
# PDBpopulation3.95.csv.gz
# PDBpopulation4.0.csv.gz

# %%
import pandas as pd

# Hardcoded file path
filename = "population3.5.csv.gz"

# Read and print the table
df = pd.read_csv(filename, compression='gzip')
df
# Out:
#       Ncomp            Ho  OmegaMatter  OmegaRadiation  OmegaLambda  \
# 0       2.0  2.181465e-18       0.3089             0.0       0.6911
# 1       2.0  2.181465e-18       0.3089             0.0       0.6911
# 2       2.0  2.181465e-18       0.3089             0.0       0.6911
# 3       2.0  2.181465e-18       0.3089             0.0       0.6911
# 4       2.0  2.181465e-18       0.3089             0.0       0.6911
# ...     ...           ...          ...             ...          ...
# 4995    2.0  2.181465e-18       0.3089             0.0       0.6911
# 4996    2.0  2.181465e-18       0.3089             0.0       0.6911
# 4997    2.0  2.181465e-18       0.3089             0.0       0.6911
# 4998    2.0  2.181465e-18       0.3089             0.0       0.6911
# 4999    2.0  2.181465e-18       0.3089             0.0       0.6911
#
#       pow_redshift  max_redshift  min_redshift  min_mass1_source    alpha0  \
# 0        -0.281897           4.0           0.0               1.0 -4.107011
# 1         1.702773           4.0           0.0               1.0 -4.660763
# 2        -0.896337           4.0           0.0               1.0 -3.384891
# 3         0.036576           4.0           0.0               1.0 -4.502164
# 4         1.267195           4.0           0.0               1.0 -4.054802
# ...            ...           ...           ...               ...       ...
# 4995      1.633798           4.0           0.0               1.0 -4.093630
# 4996     -0.097005           4.0           0.0               1.0 -3.800843
# 4997      1.231554           4.0           0.0               1.0 -4.304311
# 4998      1.481955           4.0           0.0               1.0 -4.183242
# 4999      0.114571           4.0           0.0               1.0 -4.598551
#
#       ...  max_spin2_cos_polar_angle_spin2_polar_angle_1_mass2_source_0  \
# 0     ...                                                1.0
# 1     ...                                                1.0
# 2     ...                                                1.0
# 3     ...                                                1.0
# 4     ...                                                1.0
# ...   ...                                                ...
# 4995  ...                                                1.0
# 4996  ...                                                1.0
# 4997  ...                                                1.0
# 4998  ...                                                1.0
# 4999  ...                                                1.0
#
#       mean_spin2_cos_polar_angle_spin2_polar_angle_1_mass2_source_0  \
# 0                                                   1.0
# 1                                                   1.0
# 2                                                   1.0
# 3                                                   1.0
# 4                                                   1.0
# ...                                                 ...
# 4995                                                1.0
# 4996                                                1.0
# 4997                                                1.0
# 4998                                                1.0
# 4999                                                1.0
#
#       stdv_spin2_cos_polar_angle_spin2_polar_angle_1_mass2_source_0  \
# 0                                              2.603486
# 1                                              1.110268
# 2                                              3.423620
# 3                                              1.902493
# 4                                              1.704892
# ...                                                 ...
# 4995                                           3.949119
# 4996                                           3.881356
# 4997                                           0.264466
# 4998                                           0.263159
# 4999                                           2.467695
#
#       mixture_frac_spin2_polar_angle_1_mass2_source_0  \
# 0                                            0.486428
# 1                                            0.584108
# 2                                            0.512174
# 3                                            0.893933
# 4                                            0.130997
# ...                                               ...
# 4995                                         0.310451
# 4996                                         0.379281
# 4997                                         0.817894
# 4998                                         0.800708
# 4999                                         0.672710
#
#       mixture_frac_spin2_polar_angle_0_mass2_source_1  \
# 0                                            0.253997
# 1                                            0.702172
# 2                                            0.099027
# 3                                            0.677479
# 4                                            0.167043
# ...                                               ...
# 4995                                         0.305494
# 4996                                         0.244832
# 4997                                         0.466855
# 4998                                         0.577765
# 4999                                         0.378980
#
#       min_spin2_cos_polar_angle_spin2_polar_angle_1_mass2_source_1  \
# 0                                                  -1.0
# 1                                                  -1.0
# 2                                                  -1.0
# 3                                                  -1.0
# 4                                                  -1.0
# ...                                                 ...
# 4995                                               -1.0
# 4996                                               -1.0
# 4997                                               -1.0
# 4998                                               -1.0
# 4999                                               -1.0
#
#       max_spin2_cos_polar_angle_spin2_polar_angle_1_mass2_source_1  \
# 0                                                   1.0
# 1                                                   1.0
# 2                                                   1.0
# 3                                                   1.0
# 4                                                   1.0
# ...                                                 ...
# 4995                                                1.0
# 4996                                                1.0
# 4997                                                1.0
# 4998                                                1.0
# 4999                                                1.0
#
#       mean_spin2_cos_polar_angle_spin2_polar_angle_1_mass2_source_1  \
# 0                                                   1.0
# 1                                                   1.0
# 2                                                   1.0
# 3                                                   1.0
# 4                                                   1.0
# ...                                                 ...
# 4995                                                1.0
# 4996                                                1.0
# 4997                                                1.0
# 4998                                                1.0
# 4999                                                1.0
#
#       stdv_spin2_cos_polar_angle_spin2_polar_angle_1_mass2_source_1  \
# 0                                              1.080355
# 1                                              0.422031
# 2                                              1.864892
# 3                                              3.458404
# 4                                              2.175740
# ...                                                 ...
# 4995                                           3.871144
# 4996                                           2.871797
# 4997                                           0.429518
# 4998                                           0.552869
# 4999                                           1.665504
#
#       mixture_frac_spin2_polar_angle_1_mass2_source_1
# 0                                            0.746003
# 1                                            0.297828
# 2                                            0.900973
# 3                                            0.322521
# 4                                            0.832957
# ...                                               ...
# 4995                                         0.694506
# 4996                                         0.755168
# 4997                                         0.533145
# 4998                                         0.422235
# 4999                                         0.621020
#
# [5000 rows x 73 columns]
