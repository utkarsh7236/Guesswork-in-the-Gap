# %%
import sys
import numpy
import matplotlib.pyplot as plt, pandas as pd, matplotlib as mpl, random
from scipy.ndimage import label


def utkarshGrid(): plt.minorticks_on() ; plt.grid(color='grey',which='minor',linestyle=":",linewidth='0.1',) ; plt.grid(color='black',which='major',linestyle=":",linewidth='0.1',); return None
def utkarshGridAX(ax): ax.minorticks_on() ; ax.grid(color='grey',which='minor',linestyle=":",linewidth='0.1',) ; ax.grid(color='black',which='major',linestyle=":",linewidth='0.1',); return None
mpl.rcParams['legend.frameon'], mpl.rcParams['figure.autolayout'] = False, True,
colour = ["dodgerblue", "goldenrod", "crimson", "teal", "yellowgreen", "grey"]
plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Palatino"],})
def utkarshWrapper(): plt.legend();plt.utkarshGrid() ;plt.gca().tick_params(direction='in', which='both', right=True, top=True); plt.tight_layout(); return None
def utkarshWrapperAX(ax): utkarshGridAX(ax); ax.tick_params(direction='in', which='both', right=True, top=True); return None;
plt.utkarshGrid = utkarshGrid; plt.utkarshWrapper = utkarshWrapper
def colour_sample(n = 2, col = colour, seed = 7236): random.seed(seed) ; return random.sample(colour, n)
plt.rcParams["image.cmap"] = "Set2" # I recommend, Set2, Dark2
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=colour) # Use your own OR plt.cm.Set2.colors

# %%
import os
import glob
import re
import pandas as pd

# Define pattern to match values from lines
prob_pattern = r"Probability: P\(mass <= max_mass\(spin, eos\)\) = ([\d\.eE+-]+) \+/- ([\d\.eE+-]+)"
odds_pattern = r"Odds Ratio\s*:.*= ([\d\.eE+-]+) \+/- ([\d\.eE+-]+)"

# Create list to hold parsed data
data = []

# Loop through all .out files
for filepath in glob.glob("*.out"):
    with open(filepath, "r") as f:
        content = f.read()

        prob_match = re.search(prob_pattern, content)
        odds_match = re.search(odds_pattern, content)

        if prob_match and odds_match:
            prob, prob_err = map(float, prob_match.groups())
            odds, odds_err = map(float, odds_match.groups())
            data.append({
                "filename": filepath,
                "probability": prob,
                "prob_error": prob_err,
                "odds_ratio": odds,
                "odds_error": odds_err
            })
        else:
            print(f"Warning: Could not parse values from {filepath}")

# Convert to pandas DataFrame
df = pd.DataFrame(data)
# Out:
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+2.95+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.25+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.05+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.95+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.9+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.6+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+2.3+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+2.75+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+2.5+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+2.6+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.85+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.0+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.35+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+2.85+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.75+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+2.2+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+2.65+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+2.55+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.3+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+2.35+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+2.7+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.8+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+2.8+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+2.4+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+2.25+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.65+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+2.9+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.5+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.1+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+4.0+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.15+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+2.45+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.7+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.4+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.2+component2.out
# Warning: Could not parse values from GW190814_posterior_samplesTEST+Farah2022-i-PDB+gamma_low+3.55+component2.out

# %%
df["gamma_low"] = df["filename"].str.extract(r"gamma_low\+([\d.]+)").astype(float)
df["event"] = df["filename"].str.extract(r"^(GW\d+)")
df["component"] = df["filename"].str.extract(r"component(\d+)").astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df["gamma_low"] = df["filename"].str.extract(r"gamma_low\+([\d.]+)").astype(float)
#       2 df["event"] = df["filename"].str.extract(r"^(GW\d+)")
#       3 df["component"] = df["filename"].str.extract(r"component(\d+)").astype(int)
#
# File /fs/lustre/scratch/mali/.venv/lib64/python3.11/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File /fs/lustre/scratch/mali/.venv/lib64/python3.11/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'filename'

# %%
GW190917_m1 = df[(df['event'] == "GW190917") & (df['component'] == 1)].sort_values(by="gamma_low").reset_index(drop=True)
GW190917_m2 = df[(df['event'] == "GW190917") & (df['component'] == 2)].sort_values(by="gamma_low").reset_index(drop=True)
GW230529_m1 = df[(df['event'] == "GW230529") & (df['component'] == 1)].sort_values(by="gamma_low").reset_index(drop=True)
GW190814_m2 = df[(df['event'] == "GW190814") & (df['component'] == 2)].sort_values(by="gamma_low").reset_index(drop=True)
GW190425_m1 = df[(df['event'] == "GW190425") & (df['component'] == 1)].sort_values(by="gamma_low").reset_index(drop=True)
GW190425_m2 = df[(df['event'] == "GW190425") & (df['component'] == 2)].sort_values(by="gamma_low").reset_index(drop=True)
GW200105_m1 = df[(df['event'] == "GW200105") & (df['component'] == 1)].sort_values(by="gamma_low").reset_index(drop=True)
GW200105_m2 = df[(df['event'] == "GW200105") & (df['component'] == 2)].sort_values(by="gamma_low").reset_index(drop=True)
GW200115_m2 = df[(df['event'] == "GW200115") & (df['component'] == 2)].sort_values(by="gamma_low").reset_index(drop=True)

# %%
plt.figure()
plt.plot(GW190814_m2["gamma_low"], GW190814_m2["probability"], label="GW190814 secondary")
plt.plot(GW230529_m1["gamma_low"], GW230529_m1["probability"], label="GW230529 primary")
plt.ylabel("P(NS)")
plt.xlabel("Gamma Low")
plt.utkarshWrapper()
plt.savefig("../grid_plots/gamma_low_debug.png") 
plt.show()
