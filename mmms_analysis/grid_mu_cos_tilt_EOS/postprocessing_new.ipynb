# %%
import sys
import numpy
import matplotlib.pyplot as plt, pandas as pd, matplotlib as mpl, random
from scipy.ndimage import label


def utkarshGrid(): plt.minorticks_on() ; plt.grid(color='grey',which='minor',linestyle=":",linewidth='0.1',) ; plt.grid(color='black',which='major',linestyle=":",linewidth='0.1',); return None
def utkarshGridAX(ax): ax.minorticks_on() ; ax.grid(color='grey',which='minor',linestyle=":",linewidth='0.1',) ; ax.grid(color='black',which='major',linestyle=":",linewidth='0.1',); return None
mpl.rcParams['legend.frameon'], mpl.rcParams['figure.autolayout'] = False, True,
colour = ["dodgerblue", "goldenrod", "crimson", "teal", "yellowgreen", "grey"]
plt.rcParams.update({"text.usetex": True, "font.family": "serif", "font.serif": ["Palatino"],})
def utkarshWrapper(): plt.legend();plt.utkarshGrid() ;plt.gca().tick_params(direction='in', which='both', right=True, top=True); plt.tight_layout(); return None
def utkarshWrapperAX(ax): utkarshGridAX(ax); ax.tick_params(direction='in', which='both', right=True, top=True); return None;
plt.utkarshGrid = utkarshGrid; plt.utkarshWrapper = utkarshWrapper
def colour_sample(n = 2, col = colour, seed = 7236): random.seed(seed) ; return random.sample(colour, n)
plt.rcParams["image.cmap"] = "Set2" # I recommend, Set2, Dark2
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=colour) # Use your own OR plt.cm.Set2.colors

# %%
import os
import glob
import re
import pandas as pd

# Define pattern to match values from lines
# prob_pattern = r"Probability: P\(mass <= max_mass\(spin, eos\)\) = ([\d\.eE+-]+) \+/- ([\d\.eE+-]+)"
# odds_pattern = r"Odds Ratio\s*:.*= ([\d\.eE+-]+) \+/- ([\d\.eE+-]+)"
prob_pattern = r"Probability: P\(.*?\) = ([0-9.eE+-]+) \+/- ([0-9.eE+-]+)"
odds_pattern = r"Odds Ratio\s*:.*?= ([0-9.eE+-]+) \+/- ([0-9.eE+-]+)"


# Create list to hold parsed data
data = []

# Loop through all .out files
for filepath in glob.glob("*.out"):
    with open(filepath, "r") as f:
        content = f.read()
        prob_match = re.search(prob_pattern, content)
        odds_match = re.search(odds_pattern, content)

        if prob_match and odds_match:
            prob, prob_err = map(float, prob_match.groups())
            odds, odds_err = map(float, odds_match.groups())
            data.append({
                "filename": filepath,
                "probability": prob,
                "prob_error": prob_err,
                "odds_ratio": odds,
                "odds_error": odds_err
            })
        else:
            print(f"Warning: Could not parse values from {filepath}")

# Convert to pandas DataFrame
df = pd.DataFrame(data)
# Out:
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdbNG_betaSplit3_brokenG+mu_costilt+-0.7+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdbNG_betaSplit3_brokenG+mu_costilt+-0.3+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdbNG_betaSplit3_brokenG+mu_costilt+-0.6+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdbNG_betaSplit3_brokenG+mu_costilt+-0.9+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdbNG_betaSplit3_brokenG+mu_costilt+-1.0+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdbNG_betaSplit3_brokenG+mu_costilt+-0.4+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdbNG_betaSplit3_brokenG+mu_costilt+-0.5+component2.out
# Warning: Could not parse values from GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdbNG_betaSplit3_brokenG+mu_costilt+-0.8+component2.out

# %%
df
# Out:
#                                              filename  probability  \
# 0   GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.934107
# 1   GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.829071
# 2   GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.001323
# 3   GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.885050
# 4   GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.852557
# 5   GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.963175
# 6   GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.968590
# 7   GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.961451
# 8   GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.063221
# 9   GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.101257
# 10  GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.907860
# 11  GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.830920
# 12  GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.070926
# 13  GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.906360
# 14  GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.044659
# 15  GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.965394
# 16  GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.945791
# 17  GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.069282
# 18  GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.913765
# 19  GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.002658
# 20  GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.003636
# 21  GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.013652
# 22  GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.938964
# 23  GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.969103
# 24  GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.036083
# 25  GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.814873
# 26  GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.948465
# 27  GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.072739
# 28  GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.057165
# 29  GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.006328
# 30  GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.000390
# 31  GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.017495
# 32  GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.073830
# 33  GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.960361
# 34  GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.964680
# 35  GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.882085
# 36  GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.001689
# 37  GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin+pdb...     0.853695
# 38  GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.009151
# 39  GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.067634
# 40  GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.099017
# 41  GW230529_Combined_PHM_highSpin+pdbNG_betaSplit...     0.020649
#
#     prob_error  odds_ratio  odds_error
# 0     0.003143   14.176167    0.723919
# 1     0.006304    4.850372    0.215760
# 2     0.000552    0.001325    0.000554
# 3     0.004552    7.699426    0.344504
# 4     0.005670    5.782274    0.260810
# 5     0.002119   26.155744    1.562457
# 6     0.002083   30.836616    2.110809
# 7     0.003194   24.940937    2.149124
# 8     0.015358    0.067487    0.017500
# 9     0.021101    0.112666    0.026123
# 10    0.004044    9.853079    0.476367
# 11    0.006526    4.914357    0.228290
# 12    0.017163    0.076340    0.019884
# 13    0.003986    9.679196    0.454582
# 14    0.014694    0.046746    0.016100
# 15    0.002144   27.896826    1.789938
# 16    0.002733   17.447194    0.930169
# 17    0.018719    0.074440    0.021609
# 18    0.004072   10.596251    0.547624
# 19    0.001142    0.002665    0.001148
# 20    0.001315    0.003649    0.001325
# 21    0.004708    0.013841    0.004839
# 22    0.003119   15.383663    0.837158
# 23    0.002346   31.365308    2.457476
# 24    0.010274    0.037434    0.011057
# 25    0.007548    4.401698    0.220250
# 26    0.002765   18.404327    1.041205
# 27    0.017823    0.078445    0.020728
# 28    0.017291    0.060630    0.019451
# 29    0.002505    0.006368    0.002537
# 30    0.000170    0.000390    0.000170
# 31    0.006210    0.017806    0.006433
# 32    0.018898    0.079716    0.022031
# 33    0.002141   24.227506    1.362729
# 34    0.002427   27.312877    1.945239
# 35    0.004595    7.480670    0.330483
# 36    0.000632    0.001692    0.000634
# 37    0.005637    5.835053    0.263350
# 38    0.003687    0.009236    0.003756
# 39    0.017782    0.072541    0.020456
# 40    0.022399    0.109898    0.027593
# 41    0.007971    0.021084    0.008311

# %%
pop_parameter = "mu_costilt" 
df[pop_parameter] = df["filename"].str.extract(
    rf"{re.escape(pop_parameter)}\+([+-]?(?:\d+(?:\.\d*)?|\.\d+)(?:[eE][+-]?\d+)?)",
    expand=False
).astype(float)
df["event"] = df["filename"].str.extract(r"^(GW\d+)")
df["component"] = df["filename"].str.extract(r"component(\d+)").astype(int)

# %%
GW190917_m1 = df[(df['event'] == "GW190917") & (df['component'] == 1)].sort_values(by=pop_parameter).reset_index(drop=True)
GW190917_m2 = df[(df['event'] == "GW190917") & (df['component'] == 2)].sort_values(by=pop_parameter).reset_index(drop=True)
GW230529_m1 = df[(df['event'] == "GW230529") & (df['component'] == 1)].sort_values(by=pop_parameter).reset_index(drop=True)
GW190814_m2 = df[(df['event'] == "GW190814") & (df['component'] == 2)].sort_values(by=pop_parameter).reset_index(drop=True)
GW190425_m1 = df[(df['event'] == "GW190425") & (df['component'] == 1)].sort_values(by=pop_parameter).reset_index(drop=True)
GW190425_m2 = df[(df['event'] == "GW190425") & (df['component'] == 2)].sort_values(by=pop_parameter).reset_index(drop=True)
GW200105_m1 = df[(df['event'] == "GW200105") & (df['component'] == 1)].sort_values(by=pop_parameter).reset_index(drop=True)
GW200105_m2 = df[(df['event'] == "GW200105") & (df['component'] == 2)].sort_values(by=pop_parameter).reset_index(drop=True)
GW200115_m2 = df[(df['event'] == "GW200115") & (df['component'] == 2)].sort_values(by=pop_parameter).reset_index(drop=True)

# %%
plt.figure()
objects_lst = [GW230529_m1, GW190814_m2, GW190917_m2, GW190917_m1, GW190425_m2, GW190425_m1, GW200105_m2, GW200105_m1, GW200115_m2]
objects_names = ["GW230529 primary", "GW190814 secondary", "GW190917 secondary", "GW190917 primary", "GW190425 secondary", "GW190425 primary", "GW200105 secondary", "GW200105 primary", "GW200115 secondary"]
objects_colors = [ plt.get_cmap("nipy_spectral")(i / (len(objects_lst) - 1)) for i in range(len(objects_lst))]

for i in range(len(objects_lst)):
    curr = objects_lst[i]
    curr_name = objects_names[i]
    p05 = curr["probability"] - curr["prob_error"] * 2
    p95 = curr["probability"] + curr["prob_error"] * 2
    if i == len(objects_lst) - 1:
        lab = "95\% CI"
    else:
        lab = None
    plt.plot(curr[pop_parameter], curr["probability"], label=curr_name, color = objects_colors[i])
    plt.fill_between(curr[pop_parameter], p05, p95, color="grey", alpha=0.2, label=lab)

plt.ylabel("P(NS)")
plt.xlabel(f"{pop_parameter}")
plt.utkarshWrapper()
plt.savefig(f"../grid_plots/{pop_parameter}_EOS.png") 
plt.show()
