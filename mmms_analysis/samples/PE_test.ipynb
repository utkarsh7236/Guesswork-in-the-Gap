# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
event_samples = pd.read_csv("GW230529_Combined_PHM_highSpin.csv.gz")
bns = event_samples[event_samples["mass1_source"] < 2.5]
display(len(bns))
display(len(event_samples))
# Out:
# 1267
# 23988

# %%
event_samples = pd.read_csv("GW190425_C01:IMRPhenomPv2_NRTidal:HighSpin.csv.gz")
bns = event_samples[event_samples["mass1_source"] < 2.5]
display(len(bns))
display(len(event_samples))
# Out:
# 15619
# 17782

# %%
event_samples = pd.read_csv("Prod-BBH-LowSpin1-LowSpin2.csv.gz")
bns = event_samples[event_samples["mass1_source"] < 2.5]
display(len(bns))
display(len(event_samples))
# Out:
# 0
# 9344
